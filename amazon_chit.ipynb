# %%
import pandas as pd

df = pd.read_csv("/content/Top-100 Trending Books.csv")

# %%
df.head()
# Out:
#    Rank                                         book title  book price  \
# 0     1                       Iron Flame (The Empyrean, 2)       18.42
# 1     2                                    The Woman in Me       20.93
# 2     3                                  My Name Is Barbra       31.50
# 3     4  Friends, Lovers, and the Big Terrible Thing: A...       23.99
# 4     5                              How to Catch a Turkey        5.65
#
#    rating            author  year of publication               genre  \
# 0     4.1    Rebecca Yarros                 2023     Fantasy Romance
# 1     4.5    Britney Spears                 2023              Memoir
# 2     4.5  Barbra Streisand                 2023       Autobiography
# 3     4.4     Matthew Perry                 2023              Memoir
# 4     4.8      Adam Wallace                 2018  Childrens, Fiction
#
#                                                  url
# 0  amazon.com/Iron-Flame-Empyrean-Rebecca-Yarros/...
# ...

# %%
#Row wise

subset1 = df.head(10)
subset2 = df[df['book price'] > 10]

# %%
subset1
# Out:
#    Rank                                         book title  book price  \
# 0     1                       Iron Flame (The Empyrean, 2)       18.42
# 1     2                                    The Woman in Me       20.93
# 2     3                                  My Name Is Barbra       31.50
# 3     4  Friends, Lovers, and the Big Terrible Thing: A...       23.99
# 4     5                              How to Catch a Turkey        5.65
# 5     6                      Fourth Wing (The Empyrean, 1)       16.99
# 6     7  Unwoke: How to Defeat Cultural Marxism in America       27.43
# 7     8          No Brainer (Diary of a Wimpy Kid Book 18)        8.55
# 8     9  Killers of the Flower Moon: The Osage Murders ...        9.86
# 9    10               All the Light We Cannot See: A Novel       11.98
#
#    rating            author  year of publication                   genre  \
# 0     4.1    Rebecca Yarros                 2023         Fantasy Romance
# ...

# %%
subset2
# Out:
#     Rank                                         book title  book price  \
# 0      1                       Iron Flame (The Empyrean, 2)       18.42
# 1      2                                    The Woman in Me       20.93
# 2      3                                  My Name Is Barbra       31.50
# 3      4  Friends, Lovers, and the Big Terrible Thing: A...       23.99
# 5      6                      Fourth Wing (The Empyrean, 1)       16.99
# 6      7  Unwoke: How to Defeat Cultural Marxism in America       27.43
# 9     10               All the Light We Cannot See: A Novel       11.98
# 10    11  The Ballad of Songbirds and Snakes (A Hunger G...       10.99
# 12    13  Atomic Habits: An Easy & Proven Way to Build G...       13.79
# 14    15                               The 48 Laws of Power       13.82
# 15    16  The Great Disappearance: 31 Ways to be Rapture...       18.84
# 16    17                      Lessons in Chemistry: A Novel       15.37
# ...

# %%
merged_subsets = pd.concat([subset1, subset2])

# %%
merged_subsets
# Out:
#     Rank                                         book title  book price  \
# 0      1                       Iron Flame (The Empyrean, 2)       18.42
# 1      2                                    The Woman in Me       20.93
# 2      3                                  My Name Is Barbra       31.50
# 3      4  Friends, Lovers, and the Big Terrible Thing: A...       23.99
# 4      5                              How to Catch a Turkey        5.65
# ..   ...                                                ...         ...
# 89    90  Harry Potter and the Prisoner of Azkaban (Harr...       25.97
# 93    94  Percy Jackson and the Olympians: The Chalice o...       15.63
# 95    96  First Little Readers Parent Pack: Guided Readi...       11.40
# 97    98  The Wager: A Tale of Shipwreck, Mutiny and Murder       15.30
# 98    99  I'm Dead, Now What?: Important Information Abo...       12.99
#
#     rating              author  year of publication  \
# ...

# %%
sorted_df = df.sort_values(by='book price', ascending=False)

# %%
#Transpose df
transpose_df = df.head(10).T

# %%
transpose_df
# Out:
#                                                                      0  \
# Rank                                                                 1
# book title                                Iron Flame (The Empyrean, 2)
# book price                                                       18.42
# rating                                                             4.1
# author                                                  Rebecca Yarros
# year of publication                                               2023
# genre                                                  Fantasy Romance
# url                  amazon.com/Iron-Flame-Empyrean-Rebecca-Yarros/...
#
#                                                                      1  \
# Rank                                                                 2
# book title                                             The Woman in Me
# book price                                                       20.93
# ...

# %%
melt_df = df.head(5).melt(id_vars=["book title"])

# %%
melt_df
# Out:
#                                            book title             variable  \
# 0                        Iron Flame (The Empyrean, 2)                 Rank
# 1                                     The Woman in Me                 Rank
# 2                                   My Name Is Barbra                 Rank
# 3   Friends, Lovers, and the Big Terrible Thing: A...                 Rank
# 4                               How to Catch a Turkey                 Rank
# 5                        Iron Flame (The Empyrean, 2)           book price
# 6                                     The Woman in Me           book price
# 7                                   My Name Is Barbra           book price
# 8   Friends, Lovers, and the Big Terrible Thing: A...           book price
# 9                               How to Catch a Turkey           book price
# 10                       Iron Flame (The Empyrean, 2)               rating
# ...

# %%
subset3 = df[[  'book title']]
subset4 = df[['genre']]

# %%
merged_subsets2 = pd.concat([subset3, subset4], axis=1)

# %%
merged_subsets2
# Out:
#                                            book title  \
# 0                        Iron Flame (The Empyrean, 2)
# 1                                     The Woman in Me
# 2                                   My Name Is Barbra
# 3   Friends, Lovers, and the Big Terrible Thing: A...
# 4                               How to Catch a Turkey
# ..                                                ...
# 95  First Little Readers Parent Pack: Guided Readi...
# 96                                            Hatchet
# 97  The Wager: A Tale of Shipwreck, Mutiny and Murder
# 98  I'm Dead, Now What?: Important Information Abo...
# 99                                   The Wonky Donkey
#
#                                                 genre
# 0                                     Fantasy Romance
# 1                                              Memoir
# 2                                       Autobiography
# 3                                              Memoir
# ...
